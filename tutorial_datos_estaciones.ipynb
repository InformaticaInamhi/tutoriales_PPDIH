# %% [markdown]
# # Tutorial para acceso a datos del Banco Nacional de Información Hidrometeorológico BANADIH. V.1.0.0
#
# | Fecha de Actualización | Descripción de la Actualización                                | Responsable          |
# |------------------------|---------------------------------------------------------------|----------------------|
# | 2025-04-26             | Se añade la libreria de conexion al Banco Nacional de Información Hidroemteorológica __BANADIH__ | Darwin Rosero           |
# | 2025-04-29             | Ejemplos de consultas básicas | Darwin Rosero           |
# | ******            | ****** | ******           |
#
# El siguiente libro sirve como ejemplo para consultar datos hidrometeorológicos en la infraestructura del INAMHI.

# %% [markdown]
# # Instalación de LaTeX en el entorno del usuario
#
# Si se queire activar el compilador de LaTeX, en el usuario de debera ejecutar la sigueinte linea de código en el usuario
# ```python
# !pip install jupyterlab-latex
# ```

# %% [markdown]
# # 1. Importante! Sección de librerías.
# Esta sección es para importar todas las librerías necesarías, aqui se deben realizar todos las importaciones, la librería que es obligatoría si se quiere consultar datos desde el __BAnco NAcional De Información Hidrometeorológica__. es la siguiente:
# ```python
# from banadih import con_db
# ```
# Tambien se deben importar aquí todas las librerías que se requieran para ejecutar el script.

# %%
# Importamos la librería que permite conectarse al Baknco Nacional de Información Hidrometeorlógica
from banadih import con_db 
# a continuación importar todas las demas librerías.
import pandas as pd
pd.set_option('display.max_rows', 1000)  # Muestra hasta 1000 filas
pd.set_option('display.max_columns', 1000)  # Muestra hasta 1000 columnas
# libretia para manejar fechas 
from datetime import datetime, timedelta

# %% [markdown]
# ## 2 Modulos del __BAnco NAcional De Información Hidrometeorológica__
# El BANADIH esta dividido en tres módulos, cada uno cumple una función especifica y tinene un enfoque especifico de uso, a continuacion se hace una descripción de cada módulo
#
# **Módulo de tiempo real**. __paramsRT__ Contiene acceso a los datos de las observaciones en tiempo real, con la menor temporalidad posible para cada estación (5 minutos), se puede consultar continuamente, los datos meteorológicos e hidrológicos incluyen mediciones estadísticas máximas, mínimas, instantáneos, sumas y promedio de las estaciones, tanto propietarias como con estaciones externas que envían datos a nuestros servidores.
#
# **Módulo de datos históricos.** __paramsHIST__ Contiene los datos históricos de las estaciones meteorológicas e hidrológicos existentes a nivel horario, adicional esta contiene toda la Metadata necesaria para gestionar la información a nivel nacional, se puede consultar información desde el inicio de la operación de la estación registrado en la BANADIH.
#
# **Módulo de datos agregados o públicos.** __paramsPublic__. Contiene las agregaciones de las observaciones; datos diarios, decadales (cada 10 días), mensuales, anuales e índices climáticos, estos datos se entregan al público y son visualizados a través de los visores institucionales.
#
# **Módulo de datos Pronósticos.** __paramsPronos__. Contiene los valores pronosticados de la modelación númerica generada con el modelo wrf, extraido desde lso archivos tif generados diariamente.##
#
# Para realizar la consultas a los modulo del BANADIH es necesario especificar el módulo de consulta que se pretende utilizar por ejemplo si se queire consultar datos en **tiempo real** la función quedaria como lo siguiente:
#
# ``` python
#
# con_db.query_to_dataframe(query, params=con_db.paramsPublic)
# ```

# %%
## 1. Escribimos lso códigos de las estaciones que deseamos consultar.
codigos = ('M0001', 'M0002', 'M0002', 'M0004', 'M0258', 'M1036', 'M0008', 'M0031')

## 2. Creamos la cunsulta de base de datos en lenguaje SQL. (Solicitar soporte a la DIH)
query = f"""select id_estacion, codigo, punto_obs,latitud, longitud, altitud ,provincia,
canton, captor
from administrativo.vta_estaciones where codigo in {codigos}"""

## 3. Llamamos a la funcion que nos permitira retornar los datos en un dataframe de pandas (objeto python)
# Ejecutar la consulta y almacenar los resultados en un DataFrame

estaciones = con_db.query_to_dataframe(query, params=con_db.paramsHIST)

display(estaciones)
# Out:
#     id_estacion codigo             punto_obs    latitud    longitud  altitud  \
# 0            26  M0004     RUMIPAMBA SALCEDO  -1.020000  -78.594600  2685.00
# 1         63758  M0004     RUMIPAMBA SALCEDO  -1.020000  -78.594600  2685.00
# 2            23  M0031                 CAÑAR  -2.552200  -78.945200  3083.00
# 3         63760  M0031                 CAÑAR  -2.552200  -78.945200  3083.00
# 4            12  M0002               LA TOLA  -0.231789  -78.370433  2493.00
# 5         63757  M0002               LA TOLA  -0.231789  -78.370433  2493.00
# 6            13  M0258            QUEROCHACA  -1.367100  -78.605539  2865.00
# 7         63759  M0258            QUEROCHACA  -1.367100  -78.605539  2865.00
# 8         63767  M0008                  PUYO  -1.505700  -77.956000   956.00
# 9             2  M0008                  PUYO  -1.505700  -77.956000   956.00
# 10        63427  M1036  RIOBAMBA POLITECNICA  -1.650833  -78.685214  2850.00
# 11        63772  M1036  RIOBAMBA POLITECNICA  -1.650833  -78.685214  2850.00
# 12        62416  M0001             INGUINCHO   0.256938  -78.405238  3140.00
# 13        63755  M0001             INGUINCHO   0.256938  -78.405238  3140.00
#
#      provincia    canton           captor
# 0     COTOPAXI   SALCEDO  ELECTROMECANICA
# 1     COTOPAXI   SALCEDO           MANUAL
# 2        CAÑAR     CAÑAR  ELECTROMECANICA
# 3        CAÑAR     CAÑAR           MANUAL
# 4    PICHINCHA     QUITO  ELECTROMECANICA
# 5    PICHINCHA     QUITO           MANUAL
# 6   TUNGURAHUA  CEVALLOS  ELECTROMECANICA
# 7   TUNGURAHUA  CEVALLOS           MANUAL
# 8      PASTAZA   PASTAZA           MANUAL
# 9      PASTAZA   PASTAZA  ELECTROMECANICA
# 10  CHIMBORAZO  RIOBAMBA  ELECTROMECANICA
# 11  CHIMBORAZO  RIOBAMBA           MANUAL
# 12    IMBABURA   OTAVALO  ELECTROMECANICA
# 13    IMBABURA   OTAVALO           MANUAL

# %% [markdown]
# ## 3.2 Consulta de parámetros existentes en base de datos con sus ***NEMONICOS***
# En este ejemplo consultaremos la parámetros disponibles en base de datos con sus NEMONICOS, que son los nombres estandarizados que damos a las variables observadas, para el caso de observaciones todos los nemonicos se definiran a escala de 1 hora, es decir, **por ejemplo las observaciones de las estaciones convencionales de las horas principales a las 07, 10, 13, 16, 17 horas respectivamente seran consideradas observaciones horarias**,
#
# Asi como las observaciones que se realicen las 24 horas del día tambien se consideran como observaciones de una hora por tanto lso nemónicos terminaran en **1h**
#
# en cuanto a las observaciones de las estaciones automáticas, por facilidad de nomenclatura, tambien se consideran de una hora, por lo que sus nemonicos terminan en **1h**

# %%
# consulta de parametrosabs
query = """select nemonico_2, parametro, unidad_medida, estadistico,unidad_medida_tiempo,
intervalo_tiempo, nemonico from administrativo.vta_parametros 
where unidad_medida_tiempo = 'HORAS' """
## 3. Llamamos a la funcion que nos permitira retornar los datos en un dataframe de pandas (objeto python)
# Ejecutar la consulta y almacenar los resultados en un DataFrame

parametros = con_db.query_to_dataframe(query, params=con_db.paramsHIST)

parametros
# Out:
#      nemonico_2                                          parametro  \
# 0    146060101h                                           ALUMINIO
# 1    146121601h                                           ALUMINIO
# 2    132041601h                                   CALIDAD DEL DATO
# 3    071271601h                               CANTIDAD TOTAL NUBES
# 4    126300101h                                             CAUDAL
# 5    126301601h                                             CAUDAL
# 6    126300401h                                             CAUDAL
# 7    126300201h                                             CAUDAL
# 8    133301601h                           CAUDAL DE AGUA OBSERVADO
# 9    138351601h                                     CIANOBACTERIAS
# 10   136331601h                                          CLOROFILA
# 11   143121601h                                        COLOR PT CO
# 12   142121601h                                         COLOR REAL
# 13   144361601h                                      COLOR SAC 436
# 14   002180101h                             CONDUCTIVIDAD DEL AGUA
# 15   002180401h                             CONDUCTIVIDAD DEL AGUA
# 16   002180201h                             CONDUCTIVIDAD DEL AGUA
# 17   002181601h                             CONDUCTIVIDAD DEL AGUA
# 18   131320401h          CONTENIDO VOLUMETRICO DE AGUA EN EL SUELO
# 19   131320101h          CONTENIDO VOLUMETRICO DE AGUA EN EL SUELO
# 20   131030101h          CONTENIDO VOLUMETRICO DE AGUA EN EL SUELO
# 21   131030201h          CONTENIDO VOLUMETRICO DE AGUA EN EL SUELO
# 22   131320201h          CONTENIDO VOLUMETRICO DE AGUA EN EL SUELO
# 23   131030401h          CONTENIDO VOLUMETRICO DE AGUA EN EL SUELO
# 24   131010201h          CONTENIDO VOLUMETRICO DE AGUA EN EL SUELO
# 25   141121601h                                          COT (5MM)
# 26   004020201h                               DIRECCION DEL VIENTO
# 27   004021601h                               DIRECCION DEL VIENTO
# 28   004020401h                               DIRECCION DEL VIENTO
# 29   004023201h                               DIRECCION DEL VIENTO
# 30   004020101h                               DIRECCION DEL VIENTO
# 31   004026501h                               DIRECCION DEL VIENTO
# 32   004030401h                               DIRECCION DEL VIENTO
# 33   006140401h                                        EVAPORACION
# 34   006141601h                                        EVAPORACION
# 35   006140101h                                        EVAPORACION
# 36   006140201h                                        EVAPORACION
# 37   180041601h                                 FECHA (AAAA-MM-DD)
# 38   153041601h                        FECHA (AAAA-MM-DD hh:mm:ss)
# 39   152041601h                             FECHA (AAAAMMDDhhmmss)
# 40   181041601h                                   FECHA (hh:mm:ss)
# 41   101041601h                                         FECHA_ANIO
# 42   073041601h                           FENOMENOS METEOROLOGICOS
# 43   137341601h                                        FICOCIANINA
# 44   149121601h                                            FOSFORO
# 45   130281601h                                         HELIOFANIA
# 46   145371601h                                      HIDROCARBUROS
# 47   007061601h                                  HORA DE LA RAFAGA
# 48   079060801h                                 HORAS BRILLO SOLAR
# 49   008323201h                                  HUMEDAD DEL SUELO
# 50   008010101h                                  HUMEDAD DEL SUELO
# 51   008010201h                                  HUMEDAD DEL SUELO
# 52   008010401h                                  HUMEDAD DEL SUELO
# 53   008011601h                                  HUMEDAD DEL SUELO
# 54   008320101h                                  HUMEDAD DEL SUELO
# 55   008320201h                                  HUMEDAD DEL SUELO
# 56   008320401h                                  HUMEDAD DEL SUELO
# 57   009010401h                          HUMEDAD RELATIVA DEL AIRE
# 58   009030401h                          HUMEDAD RELATIVA DEL AIRE
# 59   009011601h                          HUMEDAD RELATIVA DEL AIRE
# 60   009010101h                          HUMEDAD RELATIVA DEL AIRE
# 61   009320401h                          HUMEDAD RELATIVA DEL AIRE
# 62   009010201h                          HUMEDAD RELATIVA DEL AIRE
# 63   009013201h                          HUMEDAD RELATIVA DEL AIRE
# 64   010040401h                                          INDICE UV
# 65   011156401h                        INTENSIDAD DE PRECIPITACION
# 66   011166401h                        INTENSIDAD DE PRECIPITACION
# 67   107031601h                     LECTURA DEL TERMOMETRO ADJUNTO
# 68   124200401h  LONGITUD DE RADIACION DE ONDA LARGA INFERIOR C...
# 69   123200401h  LONGITUD DE RADIACION DE ONDA LARGA SUPERIOR C...
# 70   147121601h                                          MANGANESO
# 71   054041601h                                      MANTENIMIENTO
# 72   139121601h                                    NITRITOS (10MM)
# 73   140121601h                                     NITRITOS (5MM)
# 74   148121601h                                          NITROGENO
# 75   014103201h                                     NIVEL DEL AGUA
# 76   014100201h                                     NIVEL DEL AGUA
# 77   014100401h                                     NIVEL DEL AGUA
# 78   014101601h                                     NIVEL DEL AGUA
# 79   014100101h                                     NIVEL DEL AGUA
# 80   179041601h                                    NUBOSIDA GENERO
# 81   128271601h                                          NUBOSIDAD
# 82   178041601h                                    NUBOSIDAD CAPAS
# 83   015121601h                                   OXIGENO DISUELTO
# 84   015120201h                                   OXIGENO DISUELTO
# 85   015120401h                                   OXIGENO DISUELTO
# 86   015120101h                                   OXIGENO DISUELTO
# 87   016311601h                                        PH DEL AGUA
# 88   135381601h                       POTENCIAL DE OXIDO REDUCCION
# 89   017140801h                                      PRECIPITACION
# 90   017150801h                                      PRECIPITACION
# 91   051140801h  PRECIPITACION TOTAL ACUMULADA DESDE EL INICIO ...
# 92   018070401h                                PRESION ATMOSFERICA
# 93   018071601h                                PRESION ATMOSFERICA
# 94   018073201h                                PRESION ATMOSFERICA
# 95   018070201h                                PRESION ATMOSFERICA
# 96   018070101h                                PRESION ATMOSFERICA
# 97   060031601h                                     PUNTO DE ROCIO
# 98   116200401h                   RADIACION DE ONDA CORTA INFERIOR
# 99   115200401h                   RADIACION DE ONDA CORTA SUPERIOR
# 100  118200401h                   RADIACION DE ONDA LARGA INFERIOR
# 101  117200401h                   RADIACION DE ONDA LARGA SUPERIOR
# 102  019200101h                                   RADIACION DIFUSA
# 103  019200801h                                   RADIACION DIFUSA
# 104  019200401h                                   RADIACION DIFUSA
# 105  019200201h                                   RADIACION DIFUSA
# 106  020200401h                                  RADIACION DIRECTA
# 107  020201601h                                  RADIACION DIRECTA
# 108  120200401h                       RADIACION NETA DE ONDA CORTA
# 109  121200401h                       RADIACION NETA DE ONDA LARGA
# 110  122200401h                               RADIACION NETA TOTAL
# 111  021200801h                             RADIACION SOLAR GLOBAL
# 112  021200401h                             RADIACION SOLAR GLOBAL
# 113  021201601h                             RADIACION SOLAR GLOBAL
# 114  021200201h                             RADIACION SOLAR GLOBAL
# 115  021200101h                             RADIACION SOLAR GLOBAL
# 116  021203201h                             RADIACION SOLAR GLOBAL
# 117  022200201h                          RADIACION SOLAR REFLEJADA
# 118  022200101h                          RADIACION SOLAR REFLEJADA
# 119  022200801h                          RADIACION SOLAR REFLEJADA
# 120  022201601h                          RADIACION SOLAR REFLEJADA
# 121  022200401h                          RADIACION SOLAR REFLEJADA
# 122  022203201h                          RADIACION SOLAR REFLEJADA
# 123  024200401h                                      RADIACION UVA
# 124  024203201h                                      RADIACION UVA
# 125  024200101h                                      RADIACION UVA
# 126  024200201h                                      RADIACION UVA
# 127  052200201h                                      RADIACION UVB
# 128  052200101h                                      RADIACION UVB
# 129  052201601h                                      RADIACION UVB
# 130  052200401h                                      RADIACION UVB
# 131  025200201h                                      RADIACION UVE
# 132  025200401h                                      RADIACION UVE
# 133  025200101h                                      RADIACION UVE
# 134  025203201h                                      RADIACION UVE
# 135  003030101h                                   RAFAGA DIRECCION
# 136  003024001h                                   RAFAGA DIRECCION
# 137  026111601h                                   RAFAGA VELOCIDAD
# 138  026110101h                                   RAFAGA VELOCIDAD
# 139  027290801h                               RECORRIDO DEL VIENTO
# 140  027100801h                               RECORRIDO DEL VIENTO
# 141  027110401h                               RECORRIDO DEL VIENTO
# 142  030030201h                               TEMPERATURA DEL AGUA
# 143  030030101h                               TEMPERATURA DEL AGUA
# 144  030031601h                               TEMPERATURA DEL AGUA
# 145  030033201h                               TEMPERATURA DEL AGUA
# 146  030030401h                               TEMPERATURA DEL AGUA
# 147  112031601h                        TEMPERATURA DEL AGUA DE MAR
# 148  029033201h                               TEMPERATURA DEL AIRE
# 149  029031601h                               TEMPERATURA DEL AIRE
# 150  029030201h                               TEMPERATURA DEL AIRE
# 151  029030401h                               TEMPERATURA DEL AIRE
# 152  029030101h                               TEMPERATURA DEL AIRE
# 153  031030201h                          TEMPERATURA DEL SENSOR UV
# 154  031030101h                          TEMPERATURA DEL SENSOR UV
# 155  031033201h                          TEMPERATURA DEL SENSOR UV
# 156  031030401h                          TEMPERATURA DEL SENSOR UV
# 157  113030401h                         TEMPERATURA DEL SENSOR UVB
# 158  032031601h                              TEMPERATURA DEL SUELO
# 159  032033201h                              TEMPERATURA DEL SUELO
# 160  032030401h                              TEMPERATURA DEL SUELO
# 161  032030101h                              TEMPERATURA DEL SUELO
# 162  032030201h                              TEMPERATURA DEL SUELO
# 163  045031601h                        TEMPERATURA DEL SUELO A 0CM
# 164  045030201h                        TEMPERATURA DEL SUELO A 0CM
# 165  045030101h                        TEMPERATURA DEL SUELO A 0CM
# 166  045033201h                        TEMPERATURA DEL SUELO A 0CM
# 167  045030401h                        TEMPERATURA DEL SUELO A 0CM
# 168  050030201h                     TEMPERATURA DEL SUELO A -100CM
# 169  050030101h                     TEMPERATURA DEL SUELO A -100CM
# 170  050033201h                     TEMPERATURA DEL SUELO A -100CM
# 171  050030401h                     TEMPERATURA DEL SUELO A -100CM
# 172  047033201h                      TEMPERATURA DEL SUELO A -10CM
# 173  047030201h                      TEMPERATURA DEL SUELO A -10CM
# 174  047030101h                      TEMPERATURA DEL SUELO A -10CM
# 175  047030401h                      TEMPERATURA DEL SUELO A -10CM
# 176  048030101h                      TEMPERATURA DEL SUELO A -20CM
# 177  048031601h                      TEMPERATURA DEL SUELO A -20CM
# 178  048030401h                      TEMPERATURA DEL SUELO A -20CM
# 179  048030201h                      TEMPERATURA DEL SUELO A -20CM
# 180  048033201h                      TEMPERATURA DEL SUELO A -20CM
# 181  049033201h                      TEMPERATURA DEL SUELO A -50CM
# 182  049030201h                      TEMPERATURA DEL SUELO A -50CM
# 183  049030401h                      TEMPERATURA DEL SUELO A -50CM
# 184  049030101h                      TEMPERATURA DEL SUELO A -50CM
# 185  044033201h                       TEMPERATURA DEL SUELO A +5CM
# 186  044030401h                       TEMPERATURA DEL SUELO A +5CM
# 187  044030201h                       TEMPERATURA DEL SUELO A +5CM
# 188  044030101h                       TEMPERATURA DEL SUELO A +5CM
# 189  046030401h                       TEMPERATURA DEL SUELO A -5CM
# 190  046030101h                       TEMPERATURA DEL SUELO A -5CM
# 191  046033201h                       TEMPERATURA DEL SUELO A -5CM
# 192  046030201h                       TEMPERATURA DEL SUELO A -5CM
# 193  033031601h                 TEMPERATURA INTERNA DEL DATALOGGER
# 194  059071601h                          TENSION DE VAPOR DEL AGUA
# 195  036171601h                                 TURBIEDAD DEL AGUA
# 196  036170101h                                 TURBIEDAD DEL AGUA
# 197  036170401h                                 TURBIEDAD DEL AGUA
# 198  036170201h                                 TURBIEDAD DEL AGUA
# 199  150111601h                                 VELOCIDAD DEL AGUA
# 200  037110201h                               VELOCIDAD DEL VIENTO
# 201  037111601h                               VELOCIDAD DEL VIENTO
# 202  037110101h                               VELOCIDAD DEL VIENTO
# 203  037090401h                               VELOCIDAD DEL VIENTO
# 204  037113201h                               VELOCIDAD DEL VIENTO
# 205  037110401h                               VELOCIDAD DEL VIENTO
# 206  072291601h               VISIBILIDAD HORIZONTAL PREVALECIENTE
# 207  039190401h                              VOLTAJE DE LA BATERIA
# 208  039190201h                              VOLTAJE DE LA BATERIA
# 209  039041601h                              VOLTAJE DE LA BATERIA
# 210  039191601h                              VOLTAJE DE LA BATERIA
#
#        unidad_medida   estadistico unidad_medida_tiempo intervalo_tiempo  \
# 0                  h           MAX                HORAS                1
# 1               mg/L          INST                HORAS                1
# 2       Adimensional          INST                HORAS                1
# 3                OCT          INST                HORAS                1
# 4               m3/s           MAX                HORAS                1
# 5               m3/s          INST                HORAS                1
# 6               m3/s          PROM                HORAS                1
# 7               m3/s           MIN                HORAS                1
# 8               m3/s          INST                HORAS                1
# 9          m cell/ml          INST                HORAS                1
# 10              ug/l          INST                HORAS                1
# 11              mg/L          INST                HORAS                1
# 92               hPa          PROM                HORAS                1
# 93               hPa          INST                HORAS                1
# 94               hPa           DEV                HORAS                1
# 95               hPa           MIN                HORAS                1
# 96               hPa           MAX                HORAS                1
# 97                °C          INST                HORAS                1
# 98              W/m²          PROM                HORAS                1
# 99              W/m²          PROM                HORAS                1
# 100             W/m²          PROM                HORAS                1
# 101             W/m²          PROM                HORAS                1
# 102             W/m²           MAX                HORAS                1
# 103             W/m²           SUM                HORAS                1
# 104             W/m²          PROM                HORAS                1
# 105             W/m²           MIN                HORAS                1
# 106             W/m²          PROM                HORAS                1
# 107             W/m²          INST                HORAS                1
# 108             W/m²          PROM                HORAS                1
# 109             W/m²          PROM                HORAS                1
# 110             W/m²          PROM                HORAS                1
# 111             W/m²           SUM                HORAS                1
# 112             W/m²          PROM                HORAS                1
# 113             W/m²          INST                HORAS                1
# 114             W/m²           MIN                HORAS                1
# 115             W/m²           MAX                HORAS                1
# 116             W/m²           DEV                HORAS                1
# 117             W/m²           MIN                HORAS                1
# 118             W/m²           MAX                HORAS                1
# 119             W/m²           SUM                HORAS                1
# 120             W/m²          INST                HORAS                1
# 121             W/m²          PROM                HORAS                1
# 122             W/m²           DEV                HORAS                1
# 123             W/m²          PROM                HORAS                1
# 124             W/m²           DEV                HORAS                1
# 125             W/m²           MAX                HORAS                1
# 126             W/m²           MIN                HORAS                1
# 127             W/m²           MIN                HORAS                1
# 128             W/m²           MAX                HORAS                1
# 129             W/m²          INST                HORAS                1
# 130             W/m²          PROM                HORAS                1
# 131             W/m²           MIN                HORAS                1
# 132             W/m²          PROM                HORAS                1
# 133             W/m²           MAX                HORAS                1
# 134             W/m²           DEV                HORAS                1
# 135               °C           MAX                HORAS                1
# 136                °       MAX ABS                HORAS                1
# 137              m/s          INST                HORAS                1
# 138              m/s           MAX                HORAS                1
# 139               km           SUM                HORAS                1
# 140                m           SUM                HORAS                1
# 141              m/s          PROM                HORAS                1
# 142               °C           MIN                HORAS                1
# 143               °C           MAX                HORAS                1
# 144               °C          INST                HORAS                1
# 145               °C           DEV                HORAS                1
# 146               °C          PROM                HORAS                1
# 147               °C          INST                HORAS                1
# 148               °C           DEV                HORAS                1
# 149               °C          INST                HORAS                1
# 150               °C           MIN                HORAS                1
# 151               °C          PROM                HORAS                1
# 152               °C           MAX                HORAS                1
# 153               °C           MIN                HORAS                1
# 154               °C           MAX                HORAS                1
# 155               °C           DEV                HORAS                1
# 156               °C          PROM                HORAS                1
# 157               °C          PROM                HORAS                1
# 158               °C          INST                HORAS                1
# 159               °C           DEV                HORAS                1
# 160               °C          PROM                HORAS                1
# 161               °C           MAX                HORAS                1
# 162               °C           MIN                HORAS                1
# 163               °C          INST                HORAS                1
# 164               °C           MIN                HORAS                1
# 165               °C           MAX                HORAS                1
# 166               °C           DEV                HORAS                1
# 167               °C          PROM                HORAS                1
# 168               °C           MIN                HORAS                1
# 169               °C           MAX                HORAS                1
# 170               °C           DEV                HORAS                1
# 171               °C          PROM                HORAS                1
# 172               °C           DEV                HORAS                1
# 173               °C           MIN                HORAS                1
# 174               °C           MAX                HORAS                1
# 175               °C          PROM                HORAS                1
# 176               °C           MAX                HORAS                1
# 177               °C          INST                HORAS                1
# 178               °C          PROM                HORAS                1
# 179               °C           MIN                HORAS                1
# 180               °C           DEV                HORAS                1
# 181               °C           DEV                HORAS                1
# 182               °C           MIN                HORAS                1
# 183               °C          PROM                HORAS                1
# 184               °C           MAX                HORAS                1
# 185               °C           DEV                HORAS                1
# 186               °C          PROM                HORAS                1
# 187               °C           MIN                HORAS                1
# 188               °C           MAX                HORAS                1
# 189               °C          PROM                HORAS                1
# 190               °C           MAX                HORAS                1
# 191               °C           DEV                HORAS                1
# 192               °C           MIN                HORAS                1
# 193               °C          INST                HORAS                1
# 194              hPa          INST                HORAS                1
# 195              NTU          INST                HORAS                1
# 196              NTU           MAX                HORAS                1
# 197              NTU          PROM                HORAS                1
# 198              NTU           MIN                HORAS                1
# 199              m/s          INST                HORAS                1
# 200              m/s           MIN                HORAS                1
# 201              m/s          INST                HORAS                1
# 202              m/s           MAX                HORAS                1
# 203               Kt          PROM                HORAS                1
# 204              m/s           DEV                HORAS                1
# 205              m/s          PROM                HORAS                1
# 206               km          INST                HORAS                1
# 207                V          PROM                HORAS                1
# 208                V           MIN                HORAS                1
# 209     Adimensional          INST                HORAS                1
# 210                V          INST                HORAS                1
#
#        nemonico
# 0    146060101h
# 1    146121601h
# 2    132041601h
# 3    071271601h
# 4      1263011h
# 5     12630161h
# 6      1263041h
# 7      1263021h
# 8     13330161h
# 9    138351601h
# 10   136331601h
# 11   143121601h
# 12   142121601h
# 13   144361601h
# 14       21811h
# 15       21841h
# 16       21821h
# 17      218161h
# 18   131320401h
# 19   131320101h
# 20      131111h
# 21      131121h
# 22   131320201h
# 23      131141h
# 24   131010201h
# 25   141121601h
# 26        4221h
# 27       42161h
# 28        4241h
# 29   004023201h
# 30        4211h
# 31   004026501h
# 32   004030401h
# 33       61441h
# 34      614161h
# 35       61411h
# 36       61421h
# 37   180041601h
# 38   153041601h
# 39   152041601h
# 40   181041601h
# 41   101041601h
# 42      734161h
# 43   137341601h
# 44   149121601h
# 45    13028161h
# 46   145371601h
# 47       76161h
# 48   079060801h
# 49   008323201h
# 50        8111h
# 51        8121h
# 52        8141h
# 53   008011601h
# 54   008320101h
# 55   008320201h
# 56   008320401h
# 57        9141h
# 58   009030401h
# 59       91161h
# 60        9111h
# 61   009320401h
# 62        9121h
# 63   009013201h
# 64       10441h
# 65   011156401h
# 66   011166401h
# 67     1073161h
# 68     1242041h
# 69     1232041h
# 70   147121601h
# 71      544161h
# 72   139121601h
# 73   140121601h
# 74   148121601h
# 75   014103201h
# 76      141021h
# 77      141041h
# 78     1410161h
# 79      141011h
# 80   179041601h
# 81    12827161h
# 82   178041601h
# 83     1512161h
# 84      151221h
# 85      151241h
# 86      151211h
# 87   016311601h
# 88   135381601h
# 89      171481h
# 90   017150801h
# 91   051140801h
# 92       18741h
# 93      187161h
# 94   018073201h
# 95       18721h
# 96       18711h
# 97      603161h
# 98     1162041h
# 99     1152041h
# 100    1182041h
# 101    1172041h
# 102     192011h
# 103     192081h
# 104     192041h
# 105     192021h
# 106     202041h
# 107    2020161h
# 108    1202041h
# 109    1212041h
# 110    1222041h
# 111     212081h
# 112     212041h
# 113    2120161h
# 114     212021h
# 115     212011h
# 116  021203201h
# 117     222021h
# 118     222011h
# 119     222081h
# 120    2220161h
# 121     222041h
# 122  022203201h
# 123     242041h
# 124  024203201h
# 125     242011h
# 126     242021h
# 127     522021h
# 128     522011h
# 129    5220161h
# 130     522041h
# 131     252021h
# 132     252041h
# 133     252011h
# 134  025203201h
# 135  003030101h
# 136  003024001h
# 137  026111601h
# 138     261111h
# 139  027290801h
# 140  027100801h
# 141  027110401h
# 142      30321h
# 143      30311h
# 144     303161h
# 145  030033201h
# 146      30341h
# 147    1123161h
# 148  029033201h
# 149     293161h
# 150      29321h
# 151      29341h
# 152      29311h
# 153  031030201h
# 154  031030101h
# 155  031033201h
# 156  031030401h
# 157     113341h
# 158     323161h
# 159  032033201h
# 160      32341h
# 161      32311h
# 162      32321h
# 163     453161h
# 164      45321h
# 165      45311h
# 166  045033201h
# 167      45341h
# 168      50321h
# 169      50311h
# 170  050033201h
# 171      50341h
# 172  047033201h
# 173      47321h
# 174      47311h
# 175      47341h
# 176      48311h
# 177    4831641h
# 178      48341h
# 179      48321h
# 180  048033201h
# 181  049033201h
# 182      49321h
# 183      49341h
# 184      49311h
# 185  044033201h
# 186      44341h
# 187      44321h
# 188      44311h
# 189      46341h
# 190      46311h
# 191  046033201h
# 192      46321h
# 193     333161h
# 194     597161h
# 195    3617161h
# 196     361711h
# 197     361741h
# 198     361721h
# 199  150111601h
# 200     371121h
# 201    3711161h
# 202     371111h
# 203  037090401h
# 204  037113201h
# 205     371141h
# 206    7229161h
# 207     391941h
# 208  039190201h
# 209  039041601h
# 210    3919161h

# %% [markdown]
# ## 3.3 Filtros de parámetros.
# En este ejemplo se realizara filtros para seleccionar aquellos parámetros que concuerden con una descripción.

# %%
# filtro al objeto parametros

variable = "temperatura aire"

mascara = parametros['parametro'].str.contains(variable,  case=False, na=False)
#    case=False: Hace la búsqueda insensible a mayúsculas/minúsculas (opcional)
#    na=False:   Trata los valores NaN/NA como si no contuvieran la cadena (devuelve False para ellos)
# Aplica la máscara para filtrar el DataFrame
parametros_filtrado = parametros[mascara]
display(parametros_filtrado)
# Out:
# Empty DataFrame
# Columns: [nemonico_2, parametro, unidad_medida, estadistico, unidad_medida_tiempo, intervalo_tiempo, nemonico]
# Index: []

# %% [markdown]
# ## 3.4 Consusltas de variables por estación al BANADIH.
# El siguiente ejempo consulta los parametros o variables disponibles por estacion, agergando la fecha del primer dato disponible y la fecha del último dato, asi como si esta operativa o no la estación.

# %%
query_info_stations = f"""
        select
        	ve.codigo ,ve.id_estacion , ve.estado_estacion ,
        	ve.categoria, ep.captor, ep.nemonico ,
        	vp.parametro, vp.unidad_medida, vp.estadistico,
        	vp.unidad_medida_tiempo, ep.fecha_primer_dato , ep.fecha_ultimo_dato ,
        	ep.numero_datos 
        from
        	administrativo.vta_estaciones ve,
        	administrativo.estaciones_parametros ep,
        	administrativo.vta_parametros vp
        where
        	ve.id_estacion = ep.id_estacion
        	and vp.nemonico_2 = ep.nemonico
        order by ve.codigo, ep.nemonico
    """
df = con_db.query_to_dataframe(query_info_stations)
display(df)
# Out:
#            codigo  id_estacion   estado_estacion      categoria  \
# 0      0051020010        66305         OPERATIVA  METEOROLOGICA
# 1      0051020010        66305         OPERATIVA  METEOROLOGICA
# 2      0051020010        66305         OPERATIVA  METEOROLOGICA
# 3      0051020040        66306         OPERATIVA  METEOROLOGICA
# 4      0051020040        66306         OPERATIVA  METEOROLOGICA
# ...           ...          ...               ...            ...
# 12358    VM01-ARG        64391  EN MANTENIMIENTO  METEOROLOGICA
# 12359    VM01-ARG        64391  EN MANTENIMIENTO  METEOROLOGICA
# 12360    VM01-ARG        64391  EN MANTENIMIENTO  METEOROLOGICA
# 12361    VM01-ARG        64391  EN MANTENIMIENTO  METEOROLOGICA
# 12362    VM01-ARG        64391  EN MANTENIMIENTO  METEOROLOGICA
#
#                 captor    nemonico                             parametro  \
# 0      ELECTROMECANICA  014101601h                        NIVEL DEL AGUA
# 1               MANUAL  017140801h                         PRECIPITACION
# 2      ELECTROMECANICA  029031601h                  TEMPERATURA DEL AIRE
# 3      ELECTROMECANICA  014101601h                        NIVEL DEL AGUA
# 4      ELECTROMECANICA  017140801h                         PRECIPITACION
# ...                ...         ...                                   ...
# 12358           MANUAL  059071601h             TENSION DE VAPOR DEL AGUA
# 12359           MANUAL  060031601h                        PUNTO DE ROCIO
# 12360           MANUAL  072291601h  VISIBILIDAD HORIZONTAL PREVALECIENTE
# 12361           MANUAL  073041601h              FENOMENOS METEOROLOGICOS
# 12362           MANUAL  128271601h                             NUBOSIDAD
#
#       unidad_medida estadistico unidad_medida_tiempo  \
# 0                 m        INST                HORAS
# 1                mm         SUM                HORAS
# 2                °C        INST                HORAS
# 3                 m        INST                HORAS
# 4                mm         SUM                HORAS
# ...             ...         ...                  ...
# 12358           hPa        INST                HORAS
# 12359            °C        INST                HORAS
# 12360            km        INST                HORAS
# 12361  Adimensional        INST                HORAS
# 12362           OCT        INST                HORAS
#
#                fecha_primer_dato          fecha_ultimo_dato  numero_datos
# 0                            NaT                        NaT           0.0
# 1                            NaT                        NaT           0.0
# 2                            NaT                        NaT           0.0
# 3                            NaT                        NaT           0.0
# 4                            NaT                        NaT           0.0
# ...                          ...                        ...           ...
# 12358 2024-07-25 03:20:31.476679 2024-07-25 03:20:31.476679           1.0
# 12359 2024-07-25 03:20:31.476679 2024-07-25 03:20:31.476679           1.0
# 12360 2024-07-25 03:20:31.476679 2025-04-30 16:05:53.495120           6.0
# 12361 2024-03-25 15:56:51.663826 2025-04-30 16:05:53.495120         307.0
# 12362 2024-07-25 02:38:01.576785 2025-06-10 16:13:54.693202          22.0
#
# [12363 rows x 13 columns]

# %%
# Definir las palabras clave a buscar en la columna 'parametro'
keywords = ["temperatura"]

# Filtrar el DataFrame por las palabras clave y donde 'numero_datos' no sea nulo
filtered_df = df[df['parametro'].str.contains('|'.join(keywords), case=False, na=False) & df['numero_datos'].notna()]

# Mostrar los resultados filtrados
filtered_df
# Out:
#            codigo  id_estacion   estado_estacion      categoria  \
# 2      0051020010        66305         OPERATIVA  METEOROLOGICA
# 5      0051020040        66306         OPERATIVA  METEOROLOGICA
# 8      0051025090        66300         OPERATIVA  METEOROLOGICA
# 13     0051027050        66283         OPERATIVA    HIDROLOGICA
# 16     0051027060        66288         OPERATIVA    HIDROLOGICA
# ...           ...          ...               ...            ...
# 12341     V_M0032        65003  EN MANTENIMIENTO  METEOROLOGICA
# 12353    VM01-ARG        64391  EN MANTENIMIENTO  METEOROLOGICA
# 12354    VM01-ARG        64391  EN MANTENIMIENTO  METEOROLOGICA
# 12355    VM01-ARG        64391  EN MANTENIMIENTO  METEOROLOGICA
# 12356    VM01-ARG        64391  EN MANTENIMIENTO  METEOROLOGICA
#
#                 captor    nemonico              parametro unidad_medida  \
# 2      ELECTROMECANICA  029031601h   TEMPERATURA DEL AIRE            °C
# 5      ELECTROMECANICA  029031601h   TEMPERATURA DEL AIRE            °C
# 8      ELECTROMECANICA  029031601h   TEMPERATURA DEL AIRE            °C
# 13     ELECTROMECANICA  029031601h   TEMPERATURA DEL AIRE            °C
# 16     ELECTROMECANICA  029031601h   TEMPERATURA DEL AIRE            °C
# ...                ...         ...                    ...           ...
# 12341           MANUAL  029031601h   TEMPERATURA DEL AIRE            °C
# 12353           MANUAL  029030101d   TEMPERATURA DEL AIRE            °C
# 12354           MANUAL  029030201d   TEMPERATURA DEL AIRE            °C
# 12355           MANUAL  029031601h   TEMPERATURA DEL AIRE            °C
# 12356           MANUAL  032031601h  TEMPERATURA DEL SUELO            °C
#
#       estadistico unidad_medida_tiempo          fecha_primer_dato  \
# 2            INST                HORAS                        NaT
# 5            INST                HORAS                        NaT
# 8            INST                HORAS                        NaT
# 13           INST                HORAS                        NaT
# 16           INST                HORAS                        NaT
# ...           ...                  ...                        ...
# 12341        INST                HORAS 2024-09-22 11:32:36.405655
# 12353         MAX                 DIAS 2024-09-29 23:28:41.240338
# 12354         MIN                 DIAS 2024-09-29 23:28:41.240338
# 12355        INST                HORAS 2024-03-25 15:56:51.663826
# 12356        INST                HORAS 2024-07-25 03:20:31.476679
#
#                fecha_ultimo_dato  numero_datos
# 2                            NaT           0.0
# 5                            NaT           0.0
# 8                            NaT           0.0
# 13                           NaT           0.0
# 16                           NaT           0.0
# ...                          ...           ...
# 12341 2025-04-09 08:56:06.992427         105.0
# 12353 2025-04-30 16:05:53.495120           6.0
# 12354 2025-04-30 16:05:53.495120           8.0
# 12355 2025-04-30 16:05:53.495120         234.0
# 12356 2024-11-12 11:42:39.359633          12.0
#
# [3408 rows x 13 columns]

# %% [markdown]
# # 4 Consulta de datos de estaciones convencionales en el módulo de tiempo real.
#
# **Módulo de tiempo real. __paramsRT__** tiene  acceso a los datos de las observaciones en tiempo real, a menor resolución temporal posible para cada estación (5 minutos en el caso de estaciones automáticas que trasnmiten por GRPS y 1 hora las que transmiten por GOES), se puede consultar continuamente y hasta tres meses hacia atras de la fecha actual
#
# ## Ejemplo 1. Consulta de parametros disponibles por estación
# La siguiente celda muestra los parametros diponibles para cada estación, y la fecha del último dato de las estaciones convencionales y automáticas.

# %%
consulta = "select id_estacion,codigo_inamhi, nemonico, captor ,fecha_primer_dato ,fecha_ultimo_dato, fecha_ultima_act from public.estaciones_parametros;"
df = con_db.query_to_dataframe(consulta, params=con_db.paramsRT)
display(df)
# Out:
#        id_estacion codigo_inamhi    nemonico           captor  \
# 0            62385         H1136  153041601h  ELECTROMECANICA
# 1            63937         M5021  021201601h  ELECTROMECANICA
# 2            63941         M5025  021201601h  ELECTROMECANICA
# 3            63942         M5026  021201601h  ELECTROMECANICA
# 4            63943         M5027  021201601h  ELECTROMECANICA
# ...            ...           ...         ...              ...
# 12557        64426         M5184  039191601h  ELECTROMECANICA
# 12558           26         M0004  037110401h  ELECTROMECANICA
# 12559           26         M0004  009010401h  ELECTROMECANICA
# 12560        62564         M0162  021200201h  ELECTROMECANICA
# 12561        63781         M1124  021200401h  ELECTROMECANICA
#
#         fecha_primer_dato   fecha_ultimo_dato           fecha_ultima_act
# 0                     NaT                 NaT 2025-05-20 21:58:20.719000
# 1     2024-07-01 09:00:00 2025-06-26 06:00:00 2025-06-26 17:40:01.683116
# 2     2024-07-01 09:00:00 2025-06-26 07:00:00 2025-06-26 17:40:01.683116
# 3     2024-07-01 09:00:00 2025-06-26 05:00:00 2025-06-26 17:40:01.683116
# 4     2024-07-01 09:00:00 2025-06-26 07:00:00 2025-06-26 17:40:01.683116
# ...                   ...                 ...                        ...
# 12557 2022-07-17 05:00:00 2025-06-26 16:00:00 2025-06-26 17:40:03.468493
# 12558 2014-07-21 22:00:00 2025-06-26 15:00:00 2025-06-26 17:40:04.110419
# 12559 2014-07-21 22:00:00 2025-06-26 15:00:00 2025-06-26 17:40:05.724376
# 12560 2014-07-21 22:00:00 2025-06-26 16:00:00 2025-06-26 17:40:02.554626
# 12561 2024-10-25 20:00:00 2025-06-25 13:00:00 2025-06-26 17:40:04.312877
#
# [12562 rows x 7 columns]

# %% [markdown]
# ## Ejemplo 2. Consulta los datos de precipitación de estaciones convencionales que transmiten por libreta electrónica.
#
# En este ejemplo vamos a consultar las estaciones convencionales que transmitieron datos de precipitación dentro de las últimas 24 horas, en libreta electrónica

# %%
fechaactual = datetime.now() # hora actual 
# NOTA: la hora esta en formato UTC, por tanto para la hora local en base de datos se debe sumar 5 horas,
# para este caso solo sumamos 4 porque queremos una hora atras la consulta
numero_horas = 1
ultimodia = fechaactual - timedelta(hours=(numero_horas+5))
fc = ultimodia.strftime('%Y-%m-%d %H:00:00')
consulta = """ SELECT rr.id_estacion, es.cod_inamhi, rr.fecha_toma_dato, rr.fecha_ingreso
            FROM convencionales._029031601h rr, estaciones AS es where es.id = rr.id_estacion and rr.fecha_toma_dato > '2025-06-03 00:00'
            order by fecha_toma_dato DESC; """
df = con_db.query_to_dataframe(consulta, params=con_db.paramsRT)

df['fecha_toma_dato_local'] = df['fecha_toma_dato'] - timedelta(hours=5)
df['fecha_ingreso_local'] = df['fecha_ingreso'] - timedelta(hours=5)
display(df)
# Out:
#       id_estacion cod_inamhi            fecha_toma_dato  \
# 0           63761      M0025 2025-09-02 18:15:43.577102
# 1           63770      M0003 2025-09-02 18:13:45.221656
# 2           63760      M0031 2025-09-02 18:09:56.238989
# 3           63771      M0024 2025-09-02 18:08:54.120688
# 4           63756      M1094 2025-09-02 15:12:11.071696
# ...           ...        ...                        ...
# 1084        64400     VM0010 2025-06-03 07:54:26.701597
# 1085        63761      M0025 2025-06-03 07:07:10.104862
# 1086        64393     VM0003 2025-06-03 06:56:01.493544
# 1087        64396     VM0006 2025-06-03 06:47:55.146934
# 1088        64394     VM0004 2025-06-03 06:02:00.138461
#
#                   fecha_ingreso      fecha_toma_dato_local  \
# 0    2025-09-02 18:18:06.467996 2025-09-02 13:15:43.577102
# 1    2025-09-02 18:15:20.330112 2025-09-02 13:13:45.221656
# 2    2025-09-02 18:11:19.751074 2025-09-02 13:09:56.238989
# 3    2025-09-02 18:10:34.901691 2025-09-02 13:08:54.120688
# 4    2025-09-02 15:13:33.986140 2025-09-02 10:12:11.071696
# ...                         ...                        ...
# 1084 2025-06-03 12:58:23.452886 2025-06-03 02:54:26.701597
# 1085 2025-06-03 12:11:20.215494 2025-06-03 02:07:10.104862
# 1086 2025-06-03 12:00:16.204738 2025-06-03 01:56:01.493544
# 1087 2025-06-03 11:51:51.329249 2025-06-03 01:47:55.146934
# 1088 2025-06-03 11:05:32.363428 2025-06-03 01:02:00.138461
#
#             fecha_ingreso_local
# 0    2025-09-02 13:18:06.467996
# 1    2025-09-02 13:15:20.330112
# 2    2025-09-02 13:11:19.751074
# 3    2025-09-02 13:10:34.901691
# 4    2025-09-02 10:13:33.986140
# ...                         ...
# 1084 2025-06-03 07:58:23.452886
# 1085 2025-06-03 07:11:20.215494
# 1086 2025-06-03 07:00:16.204738
# 1087 2025-06-03 06:51:51.329249
# 1088 2025-06-03 06:05:32.363428
#
# [1089 rows x 6 columns]

# %%
fechaactual = datetime.now() # hora actual 
# NOTA: la hora esta en formato UTC, por tanto para la hora local en base de datos se debe sumar 5 horas,
# para este caso solo sumamos 4 porque queremos una hora atras la consulta
numero_horas = 24
ultimodia = fechaactual - timedelta(hours=(numero_horas+5))
fc = ultimodia.strftime('%Y-%m-%d %H:00:00')
consulta = """ SELECT tem.id_estacion, es.cod_inamhi, tem.fecha_toma_dato, tem.fecha_ingreso, tem.term_hmd AS tem_humedo, tem.term_seco AS tem_seco 
FROM convencionales._029031601h tem, estaciones AS es where es.id = tem.id_estacion and tem.fecha_toma_dato > '2025-06-03 00:00'
order by fecha_toma_dato DESC; """
df = con_db.query_to_dataframe(consulta, params=con_db.paramsRT)

df['fecha_toma_dato_local'] = df['fecha_toma_dato'] - timedelta(hours=5)
df['fecha_ingreso_local'] = df['fecha_ingreso'] - timedelta(hours=5)
display(df)
# Out:
#       id_estacion cod_inamhi            fecha_toma_dato  \
# 0           63771      M0024 2025-11-19 13:26:14.868380
# 1           63770      M0003 2025-11-19 13:00:25.050216
# 2           63756      M1094 2025-11-19 12:14:14.232191
# 3           63767      M0008 2025-11-19 12:12:22.233859
# 4           63761      M0025 2025-11-19 12:11:32.450259
# ...           ...        ...                        ...
# 2740        64400     VM0010 2025-06-03 07:54:26.701597
# 2741        63761      M0025 2025-06-03 07:07:10.104862
# 2742        64393     VM0003 2025-06-03 06:56:01.493544
# 2743        64396     VM0006 2025-06-03 06:47:55.146934
# 2744        64394     VM0004 2025-06-03 06:02:00.138461
#
#                   fecha_ingreso tem_humedo  tem_seco  \
# 0    2025-11-19 13:35:06.320705   12.50000  15.30000
# 1    2025-11-19 13:02:59.991921    9.40000  10.00000
# 2    2025-11-19 12:16:20.178978   10.60000  12.00000
# 3    2025-11-19 12:25:56.563457   18.40000  19.00000
# 4    2025-11-19 12:13:09.523536   22.00000  22.40000
# ...                         ...        ...       ...
# 2740 2025-06-03 12:58:23.452886       None  21.20000
# 2741 2025-06-03 12:11:20.215494   21.80000  22.80000
# 2742 2025-06-03 12:00:16.204738       None  17.24000
# 2743 2025-06-03 11:51:51.329249       None  17.70000
# 2744 2025-06-03 11:05:32.363428       None  19.00000
#
#           fecha_toma_dato_local        fecha_ingreso_local
# 0    2025-11-19 08:26:14.868380 2025-11-19 08:35:06.320705
# 1    2025-11-19 08:00:25.050216 2025-11-19 08:02:59.991921
# 2    2025-11-19 07:14:14.232191 2025-11-19 07:16:20.178978
# 3    2025-11-19 07:12:22.233859 2025-11-19 07:25:56.563457
# 4    2025-11-19 07:11:32.450259 2025-11-19 07:13:09.523536
# ...                         ...                        ...
# 2740 2025-06-03 02:54:26.701597 2025-06-03 07:58:23.452886
# 2741 2025-06-03 02:07:10.104862 2025-06-03 07:11:20.215494
# 2742 2025-06-03 01:56:01.493544 2025-06-03 07:00:16.204738
# 2743 2025-06-03 01:47:55.146934 2025-06-03 06:51:51.329249
# 2744 2025-06-03 01:02:00.138461 2025-06-03 06:05:32.363428
#
# [2745 rows x 8 columns]

# %% [markdown]
# # 5 Consulta de datos de estaciones automáticas en el módulo histórico.
#
# **Módulo de datos históricos.** ***paramsHIST*** contiene los datos hostóricos de las estaciones meteorólogicas existentes, aqui se almacena toda la información observada historicamente, a pesar de que no hay limite en el periodo de consulta se debe tener en cuenta las capacidades de computo asignasdas a cada usuario.
#
# ## 5.1 Ejemplo 1. Consulta de parametros disponibles por estación
# La siguiente celda muestra los parametros diponibles para cada estación, y la fecha del último dato de las estaciones convencionales y automáticas.

# %%
consultaph = f"""select id_estacion, codigo_inamhi, captor, nemonico, numero_datos, 
descripcion_parametro, fecha_primer_dato, fecha_ultimo_dato, 
fecha_ultima_act from administrativo.estaciones_parametros;"""
dfph = con_db.query_to_dataframe(consultaph, params=con_db.paramsHIST)
dfph
# Out:
#        id_estacion codigo_inamhi           captor    nemonico  numero_datos  \
# 0            63800         H0854  ELECTROMECANICA  014100405m           0.0
# 1                4         M1170  ELECTROMECANICA  025200401h        7938.0
# 2            63920         M1273  ELECTROMECANICA  022200401h        3983.0
# 3            64426         M5184  ELECTROMECANICA  022200401h         247.0
# 4            64387         HM004  ELECTROMECANICA  143121601h        6003.0
# ...            ...           ...              ...         ...           ...
# 10639        63804         M5134  ELECTROMECANICA  009010101m           0.0
# 10640        63804         M5134  ELECTROMECANICA  009010201m           0.0
# 10641        63804         M5134  ELECTROMECANICA  009013201m           0.0
# 10642        63804         M5134  ELECTROMECANICA  018070401m           0.0
# 10643        63804         M5134  ELECTROMECANICA  018070101m           0.0
#
#                               descripcion_parametro   fecha_primer_dato  \
# 0                   NIVEL DEL AGUA m PROM 5 MINUTOS                 NaT
# 1                   RADIACION UVE W/m² PROM 1 HORAS 2024-07-01 04:00:00
# 2       RADIACION SOLAR REFLEJADA W/m² PROM 1 HORAS 2024-07-01 04:00:00
# 3       RADIACION SOLAR REFLEJADA W/m² PROM 1 HORAS 2025-05-20 21:00:00
# 4                     COLOR PT CO mg/L INST 1 HORAS 2024-08-06 20:00:00
# ...                                             ...                 ...
# 10639  HUMEDAD RELATIVA DEL AIRE % RH MAX 1 MINUTOS                 NaT
# 10640  HUMEDAD RELATIVA DEL AIRE % RH MIN 1 MINUTOS                 NaT
# 10641  HUMEDAD RELATIVA DEL AIRE % RH DEV 1 MINUTOS                 NaT
# 10642        PRESION ATMOSFERICA hPa PROM 1 MINUTOS                 NaT
# 10643         PRESION ATMOSFERICA hPa MAX 1 MINUTOS                 NaT
#
#         fecha_ultimo_dato           fecha_ultima_act
# 0                     NaT 2025-05-20 21:42:51.347306
# 1     2025-05-31 03:00:00 2025-05-31 04:00:01.359731
# 2     2024-12-16 14:00:00 2025-05-31 04:00:03.383429
# 3     2025-05-31 03:00:00 2025-05-31 04:00:03.383429
# 4     2025-05-31 02:00:00 2025-05-31 04:00:01.493956
# ...                   ...                        ...
# 10639                 NaT 2025-02-19 17:43:30.972013
# 10640                 NaT 2025-02-19 17:43:30.975011
# 10641                 NaT 2025-02-19 17:43:30.977932
# 10642                 NaT 2025-02-19 17:43:30.980970
# 10643                 NaT 2025-02-19 17:43:30.984002
#
# [10644 rows x 9 columns]

# %% [markdown]
# ## 5.2 Ejemplo 2 Parte1. Consulta de datos de estaciones automaticas de la ùltima hora
# La siguiente como consultar dastos de precipitación todas las estaciones para la última hora, se consultará únicamente las estaciones automáticas.

# %%
#### Generamos el listado de estaciones por propietario
id_pro = (12,26)  

query_propietario = f"""
    select codigo, punto_obs, propietario, id_estacion, captor, categoria, latitud, longitud, altitud
from administrativo.vta_estaciones where id_propietario in {id_pro} order by codigo;
"""
#print(query_propietario)
# Ejecutar la consulta y almacenar los resultados en un DataFrame
df_propietarios = con_db.query_to_dataframe(query_propietario)
# Mostrar los primeros registros del DataFrame
#print(df_propietarios.head(3))

ids_estaciones = df_propietarios.iloc[:,0]
ids_estaciones = tuple(ids_estaciones)
#print(ids_estaciones)

### cambiar por la nombre del nemònico que se desea consultar 
# ***********************
nemonico="017140801h"

ultimaHora = datetime.now() # hora actual 
#print(ultimaHora)
# NOTA: la hora esta en formato UTC, por tanto para la hora real en base de datos se debe sumar 5 horas,
# para este caso solo sumamos 4 porque queremos una hora atras la consulta
ultimaHora = ultimaHora + timedelta(hours=4)
formateado = ultimaHora.strftime('%Y-%m-%d %H:00:00')
#print(formateado)
consultauh = f"""SELECT rr.id_estacion, es.codigo, es.punto_obs,
rr.fecha_toma_dato, rr."1h" AS precipitacion 
FROM automaticas._{nemonico} rr, administrativo.vta_estaciones AS es
where es.id_estacion = rr.id_estacion 
and rr.fecha_toma_dato = '{formateado}' and es.codigo in {ids_estaciones}
order by rr.fecha_toma_dato, es.codigo;"""
#print(consultauh)
dfuh = con_db.query_to_dataframe(consultauh, params=con_db.paramsHIST)
#cambiamos la hora a local UTC-5
#dfuh['fecha_toma_dato'] = pd.to_datetime(dfuh['fecha_toma_dato'])
dfuh['fecha_toma_dato'] = dfuh['fecha_toma_dato'] - timedelta(hours=5)
# limpiamos el dataframe de valore None en la columna precipitación 
dfuh = dfuh.dropna(subset=['precipitacion']).reset_index(drop=True)
dfuh
# Out:
#     id_estacion codigo                        punto_obs     fecha_toma_dato  \
# 0         63937  M5021              SALVEFACHA-OYACACHI 2025-06-11 08:00:00
# 1         63941  M5025             LA VIRGEN-PAPALLACTA 2025-06-11 08:00:00
# 2         63943  M5027  SAN MARCOS-ILINIZAS (EL CHAUPI) 2025-06-11 08:00:00
# 3         63946  M5030                GORDILLO (PINTAG) 2025-06-11 08:00:00
# 4         63947  M5031             CHUMILLOS (CANGAHUA) 2025-06-11 08:00:00
# 5         64430  M5044            YARUQUI -EPMAPS QUITO 2025-06-11 08:00:00
# 6         64437  M5050          EL TROJE - EPMAPS QUITO 2025-06-11 08:00:00
# 7         66260  M5056          TOCTIUCO - EPMAPS QUITO 2025-06-11 08:00:00
# 8         66262  M5058          IZOBAMBA - EPMAPS QUITO 2025-06-11 08:00:00
# 9         64438  M5060                         EL CINTO 2025-06-11 08:00:00
# 10        63949  M5075                 ITULCACHI (PIFO) 2025-06-11 08:00:00
# 11        63951  M5077                  REI (EL CHAUPI) 2025-06-11 08:00:00
# 12        63952  M5078                      PIFO -FONAG 2025-06-11 08:00:00
# 13        64428  M5231                 RUMIPAMBA EPMAPS 2025-06-11 08:00:00
# 14        64429  M5232                       BELLAVISTA 2025-06-11 08:00:00
# 15        64432  M5234                    LA MICA PRESA 2025-06-11 08:00:00
# 16        64434  M5236                     SALVE FACCHA 2025-06-11 08:00:00
# 17        64435  M5237                       GUAYTALOMA 2025-06-11 08:00:00
# 18        66266  M5243           SAN FRANCISCO - EPMAPS 2025-06-11 08:00:00
# 19        66267  M5244               CRUZ LOMA - EPMAPS 2025-06-11 08:00:00
# 20        66268  M5245              SANTA ROSA - EPMAPS 2025-06-11 08:00:00
# 21        66269  M5246                  PICHAN - EPMAPS 2025-06-11 08:00:00
# 22        66270  M5247              PAPALLACTA - EPMAPS 2025-06-11 08:00:00
# 23        66274  M5251              PALAGUILLO - EPMAPS 2025-06-11 08:00:00
# 24        66275  M5252               EL CARMEN - EPMAPS 2025-06-11 08:00:00
# 25        66276  M5253          TANQUE SOLANDA - EPMAPS 2025-06-11 08:00:00
# 26        66277  M5254       SALVE FACCHA ALTO - EPMAPS 2025-06-11 08:00:00
# 27        66281  M5258        LAGUNA LOS PATOS - EPMAPS 2025-06-11 08:00:00
#
#    precipitacion
# 0           0.00
# 1           0.00
# 2           0.00
# 3           0.00
# 4           0.00
# 5           0.00
# 6           0.00
# 7           0.00
# 8           0.00
# 9           0.00
# 10          0.00
# 11          0.00
# 12          0.00
# 13          0.00
# 14          0.00
# 15          0.00
# 16          0.00
# 17          0.00
# 18          0.00
# 19          0.00
# 20          0.00
# 21          0.10
# 22          0.00
# 23          0.00
# 24          0.00
# 25          0.00
# 26          0.00
# 27          0.00

# %% [markdown]
# ## 5.3 Ejemplo 3 Parte 2. Consulta de datos de estaciones automaticas de las últimas 24 horas filtrando por propietario
#
# En esta sección se aplicara primero un filtro para obtener un grupo de estaciones por propietario, en este ejemplo para id_propietario 12, de EPMAPS y FONAG.

# %%
#### Generamos el listado de estaciones por propietario
id_pro = (12,26)  

query_propietario = f"""
    select codigo, punto_obs, propietario, id_estacion, captor, categoria, latitud, longitud, altitud
from administrativo.vta_estaciones where id_propietario in {id_pro} order by codigo;
"""
#print(query_propietario)
# Ejecutar la consulta y almacenar los resultados en un DataFrame
df_propietarios = con_db.query_to_dataframe(query_propietario)
# Mostrar los primeros registros del DataFrame
#print(df_propietarios.head(3))

ids_estaciones = df_propietarios.iloc[:,0]
ids_estaciones = tuple(ids_estaciones)
#print(ids_estaciones)
### cambiar por la nombre del nemònico que se desea consultar 
# ***********************
nemonico="017140801h"
numero_horas = 24
# Representa el calculo que se debe realizar en la columna agregado
agregado = 0 ## 0 para suma, 1 para promedio 
ultimaHora = datetime.now() # hora actual 
# NOTA: la hora esta en formato UTC, por tanto para la hora local en base de datos se debe sumar 5 horas,
# para este caso solo sumamos 4 porque queremos una hora atras la consulta
ultimaHora = ultimaHora - timedelta(hours=(numero_horas+4))
fc = ultimaHora.strftime('%Y-%m-%d %H:00:00')
hora = ultimaHora.strftime('%H')
print("fecha de inicio de la consulta"," - ",fc)
for i in range(numero_horas):
    consultauh = f"""SELECT rr.id_estacion, es.codigo, rr."1h" AS precipitacion 
    FROM automaticas._{nemonico} rr, administrativo.vta_estaciones AS es
    where es.id_estacion = rr.id_estacion and rr.fecha_toma_dato = '{fc}' and es.codigo in {ids_estaciones}
    order by rr.fecha_toma_dato, es.codigo;"""
    dfuh = con_db.query_to_dataframe(consultauh, params=con_db.paramsHIST)
    cod = f'codigo_{i+1}h'
    #pre = f"pre_{i+1}h"
    pre = ultimaHora.strftime('%m_%d_%H')
    dfuh.rename(columns={'codigo': cod,'precipitacion': pre }, inplace=True)
    #Unir un solo dataframe
    if i == 0:
        df_acum = dfuh
    else: 
        df_acum = pd.merge(df_acum, dfuh, on='id_estacion',how='outer')
    
    ultimaHora = ultimaHora + timedelta(hours = + 1)
    fc = ultimaHora.strftime('%Y-%m-%d %H:00:00')

df_acum
# Out:
# fecha de inicio de la consulta  -  2025-06-10 05:00:00
#     id_estacion codigo_1h 06_10_05 codigo_2h 06_10_06 codigo_3h 06_10_07  \
# 0         63937     M5021     0.00     M5021     0.00     M5021     0.00
# 1         63941     M5025     0.00     M5025     0.00     M5025     0.00
# 2         63942     M5026     0.00     M5026     0.00     M5026     0.00
# 3         63943     M5027     0.00     M5027     0.00     M5027     0.00
# 4         63944     M5028     0.00     M5028     0.00     M5028     0.00
# 5         63945     M5029     0.00     M5029     0.00     M5029     0.00
# 6         63946     M5030     0.00     M5030     0.00     M5030     0.00
# 7         63947     M5031     0.00     M5031     0.00     M5031     0.00
# 8         63949     M5075     0.00     M5075     0.00     M5075     0.00
# 9         63951     M5077     0.00     M5077     0.00     M5077     0.00
# 10        63952     M5078     0.00     M5078     0.00     M5078     0.00
# 11        64428     M5231     0.00     M5231     0.00     M5231     0.00
# 12        64429     M5232     0.00     M5232     0.00     M5232     0.00
# 13        64430     M5044     0.00     M5044     0.00     M5044     0.00
# 14        64432     M5234     0.00     M5234     0.00     M5234     0.00
# 15        64434     M5236     0.00     M5236     0.00     M5236     0.00
# 16        64435     M5237     0.00     M5237     0.00     M5237     0.00
# 17        64437     M5050     0.00     M5050     0.00     M5050     0.00
# 18        64438     M5060     0.00     M5060     0.00     M5060     0.00
# 19        66260     M5056     0.00     M5056     0.00     M5056     0.00
# 20        66262     M5058     0.00     M5058     0.00     M5058     0.00
# 21        66263     M5240     0.00     M5240     0.00     M5240     0.00
# 22        66266     M5243     0.00     M5243     0.00     M5243     0.00
# 23        66267     M5244     0.00     M5244     0.00     M5244     0.00
# 24        66268     M5245     0.00     M5245     0.00     M5245     0.00
# 25        66269     M5246     0.00     M5246     0.00     M5246     0.00
# 26        66270     M5247     0.00     M5247     0.00     M5247     0.00
# 27        66274     M5251     0.00     M5251     0.00     M5251     0.00
# 28        66275     M5252     0.00     M5252     0.00     M5252     0.00
# 29        66276     M5253     0.00     M5253     0.00     M5253     0.00
# 30        66277     M5254     0.00     M5254     0.00     M5254     0.00
# 31        66281     M5258     0.00     M5258     0.00     M5258     0.00
#
#    codigo_4h 06_10_08 codigo_5h 06_10_09 codigo_6h 06_10_10 codigo_7h  \
# 0      M5021     0.00     M5021     1.60     M5021     0.40     M5021
# 1      M5025     0.00     M5025     0.00     M5025     0.50     M5025
# 2      M5026     0.00     M5026     0.00     M5026     1.00     M5026
# 3      M5027     0.00     M5027     0.00     M5027     0.00     M5027
# 4      M5028     0.00     M5028     0.00     M5028     0.00     M5028
# 5      M5029     0.00     M5029     0.00     M5029     0.50     M5029
# 6      M5030     0.00     M5030     0.00     M5030     0.20     M5030
# 7      M5031     0.00     M5031     0.10     M5031     1.70     M5031
# 8      M5075     0.00     M5075     0.00     M5075     0.70     M5075
# 9      M5077     0.00     M5077     0.00     M5077     0.00     M5077
# 10     M5078     0.00     M5078     0.00     M5078     1.00     M5078
